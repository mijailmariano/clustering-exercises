# %%
# %matplotlib inline
import matplotlib as mlp
mlp.rcParams['figure.dpi'] = 200

# diasbling warning messages
import warnings
warnings.filterwarnings("ignore")

# importing key libraries
import pandas as pd
pd.set_option('display.max_rows', None)
import numpy as np

# importing wrangle/acquire module
import wrangle
from wrangle import get_zillow_dataset, \
                    null_df, \
                    drop_nulls, \
                    train_validate_test_split

# importing data visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()

# sklearn data science library
from sklearn.impute import KNNImputer
from sklearn.impute import MissingIndicator
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %% [markdown]
# ### ``Clustering Module: Exploratory Analysis Exercises``
#
#
# Ask at least 5 questions about the data, keeping in mind that your target variable is logerror.
#
# **``Example Questions:``**
#
# 1. Is logerror significantly different for properties in LA County vs Orange County vs Ventura County?
#
#
# *Answer these questions through a mix of statistical tests and visualizations.*
#
# **``Bonus:``**
#
# * Compute the mean(logerror) by zipcode and the overall mean(logerror). Write a loop that will run a t-test between the overall mean and the mean for each zip code.
#
# * We want to identify the zip codes where the error is significantly higher or lower than the expected error.
#
# ----

# %%
# importing zillow dataset
df = get_zillow_dataset()
df.shape
# Out:
# (52319, 68)

# %%
# cleaning dataset for feature/row null % > 80%
df = drop_nulls(df, .8, .8)
df.shape
# Out:
# (52311, 29)

# %%
# remaining nulls and percentage of feature
remaining_nulls = null_df(df)
remaining_nulls
# Out:
#                               Total Null  Feature Null %
# regionidcity                        1032        0.019728
# lotsizesquarefeet                    360        0.006882
# finishedsquarefeet12                 238        0.004550
# calculatedbathnbr                    127        0.002428
# fullbathcnt                          127        0.002428
# censustractandblock                  113        0.002160
# yearbuilt                            106        0.002026
# structuretaxvaluedollarcnt            79        0.001510
# calculatedfinishedsquarefeet          73        0.001395
# regionidzip                           23        0.000440
# taxamount                              4        0.000076
# landtaxvaluedollarcnt                  1        0.000019
# taxvaluedollarcnt                      1        0.000019
# assessmentyear                         0        0.000000
# roomcnt                                0        0.000000
# logerror                               0        0.000000
# transactiondate                        0        0.000000
# id                                     0        0.000000
# rawcensustractandblock                 0        0.000000
# regionidcounty                         0        0.000000
# parcelid                               0        0.000000
# propertylandusetypeid                  0        0.000000
# propertycountylandusecode              0        0.000000
# longitude                              0        0.000000
# latitude                               0        0.000000
# fips                                   0        0.000000
# bedroomcnt                             0        0.000000
# bathroomcnt                            0        0.000000
# propertylandusedesc                    0        0.000000

# %%
# splitting the dataset to 1. fill-in remaining nulls and 2. determine outlier cutoffs

train, validate, test = train_validate_test_split(df)
# Out:
# train shape: (29293, 29)
# validate shape: (12555, 29)
# test shape: (10463, 29)

# %%
# 2nd split: splitting larger datasets into x and y variables

X_train = train.drop(columns = "logerror")
y_train = train['logerror']

X_validate = validate.drop(columns = "logerror")
y_validate = validate['logerror']

X_test = test.drop(columns = "logerror")
y_test = test['logerror']

# %%
# viewing X_train variables/features
X_train.columns.sort_values().tolist()
# Out:
# ['assessmentyear',
#  'bathroomcnt',
#  'bedroomcnt',
#  'calculatedbathnbr',
#  'calculatedfinishedsquarefeet',
#  'censustractandblock',
#  'finishedsquarefeet12',
#  'fips',
#  'fullbathcnt',
#  'id',
#  'landtaxvaluedollarcnt',
#  'latitude',
#  'longitude',
#  'lotsizesquarefeet',
#  'parcelid',
#  'propertycountylandusecode',
#  'propertylandusedesc',
#  'propertylandusetypeid',
#  'rawcensustractandblock',
#  'regionidcity',
#  'regionidcounty',
#  'regionidzip',
#  'roomcnt',
#  'structuretaxvaluedollarcnt',
#  'taxamount',
#  'taxvaluedollarcnt',
#  'transactiondate',
#  'yearbuilt']

# %%
# checking nulls in X_train dataset

nulls_in_X = null_df(X_train)
nulls_in_X
# Out:
#                               Total Null  Feature Null %
# regionidcity                         600        0.020483
# lotsizesquarefeet                    208        0.007101
# finishedsquarefeet12                 133        0.004540
# fullbathcnt                           72        0.002458
# calculatedbathnbr                     72        0.002458
# yearbuilt                             64        0.002185
# censustractandblock                   55        0.001878
# calculatedfinishedsquarefeet          45        0.001536
# structuretaxvaluedollarcnt            41        0.001400
# regionidzip                           15        0.000512
# taxamount                              1        0.000034
# taxvaluedollarcnt                      0        0.000000
# id                                     0        0.000000
# assessmentyear                         0        0.000000
# landtaxvaluedollarcnt                  0        0.000000
# transactiondate                        0        0.000000
# roomcnt                                0        0.000000
# rawcensustractandblock                 0        0.000000
# regionidcounty                         0        0.000000
# parcelid                               0        0.000000
# propertylandusetypeid                  0        0.000000
# propertycountylandusecode              0        0.000000
# longitude                              0        0.000000
# latitude                               0        0.000000
# fips                                   0        0.000000
# bedroomcnt                             0        0.000000
# bathroomcnt                            0        0.000000
# propertylandusedesc                    0        0.000000

# %%
# classifying features/varibles by data type (discrete/continuous)

disc_lst = []
cont_lst = []

for col in list(X_train.columns):
    if X_train[col].dtype == "int" or X_train[col].dtype == "float":
        cont_lst.append(col)
    else:
        disc_lst.append(col)

print(f'Discrete Features:\n{disc_lst}')
print()
print(f'Continuous Features:\n{cont_lst}')
# Out:
# Discrete Features:
# ['propertycountylandusecode', 'transactiondate', 'propertylandusedesc']
#
# Continuous Features:
# ['id', 'parcelid', 'bathroomcnt', 'bedroomcnt', 'calculatedbathnbr', 'calculatedfinishedsquarefeet', 'finishedsquarefeet12', 'fips', 'fullbathcnt', 'latitude', 'longitude', 'lotsizesquarefeet', 'propertylandusetypeid', 'rawcensustractandblock', 'regionidcity', 'regionidcounty', 'regionidzip', 'roomcnt', 'yearbuilt', 'structuretaxvaluedollarcnt', 'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt', 'taxamount', 'censustractandblock']

# %%
# replacing null instances with "np.NaN" for better use of sklearn iterative imputer

X_train = X_train.replace('?', np.NaN)
X_train.shape
# Out:
# (29293, 28)

# %%
# using sklearn's iterative imputer to determine/fill-in remaining missing values

numeric_cols = X_train[cont_lst]

impute_it = IterativeImputer(missing_values = np.NaN, skip_complete = True, random_state = 123)
imputed_df = impute_it.fit_transform(numeric_cols)

# %%
# ensuring there are no nulls in inputed dataframe

pd.DataFrame(imputed_df, columns = cont_lst).isnull().sum()
# Out:
# id                              0
# parcelid                        0
# bathroomcnt                     0
# bedroomcnt                      0
# calculatedbathnbr               0
# calculatedfinishedsquarefeet    0
# finishedsquarefeet12            0
# fips                            0
# fullbathcnt                     0
# latitude                        0
# longitude                       0
# lotsizesquarefeet               0
# propertylandusetypeid           0
# rawcensustractandblock          0
# regionidcity                    0
# regionidcounty                  0
# regionidzip                     0
# roomcnt                         0
# yearbuilt                       0
# structuretaxvaluedollarcnt      0
# taxvaluedollarcnt               0
# assessmentyear                  0
# landtaxvaluedollarcnt           0
# taxamount                       0
# censustractandblock             0
# dtype: int64

# %%
# creating a new df for fill-in missing X_train values

missing_vals = pd.DataFrame(imputed_df, columns = cont_lst, index = X_train.index)
missing_vals.head()
# Out:
#               id    parcelid  bathroomcnt  bedroomcnt  calculatedbathnbr  \
# 35549  2835290.0  10928726.0          2.0         3.0                2.0
# 18097  1855117.0  11925904.0          3.0         4.0                3.0
# 18950  2809180.0  11991988.0          1.0         3.0                1.0
# 36943  1030712.0  10850571.0          1.0         2.0                1.0
# 52305  2871267.0  12669704.0          2.0         4.0                2.0
#
#        calculatedfinishedsquarefeet  finishedsquarefeet12    fips  \
# 35549                        1244.0                1244.0  6037.0
# 18097                        2898.0                2898.0  6037.0
# 18950                        1166.0                1166.0  6037.0
# 36943                         803.0                 803.0  6037.0
# 52305                        2166.0                2166.0  6037.0
#
#        fullbathcnt    latitude  ...  regionidcounty  regionidzip  roomcnt  \
# 35549          2.0  34166955.0  ...          3101.0      96446.0      0.0
# 18097          3.0  34120410.0  ...          3101.0      96268.0      0.0
# 18950          1.0  34078141.0  ...          3101.0      95985.0      0.0
# 36943          1.0  34177765.0  ...          3101.0      96349.0      0.0
# 52305          2.0  33809933.0  ...          3101.0      96123.0      0.0
#
#        yearbuilt  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 35549     1943.0                     32283.0            58562.0
# 18097     1993.0                    518378.0           926843.0
# 18950     1922.0                    147520.0           459788.0
# 36943     1949.0                     99494.0           497472.0
# 52305     1954.0                     66047.0           139547.0
#
#        assessmentyear  landtaxvaluedollarcnt  taxamount  censustractandblock
# 35549          2016.0                26279.0     764.51         6.037125e+13
# 18097          2016.0               408465.0   10802.46         6.037432e+13
# 18950          2016.0               312268.0    5518.32         6.037193e+13
# 36943          2016.0               397978.0    6099.58         6.037139e+13
# 52305          2016.0                73500.0    1770.95         6.037651e+13
#
# [5 rows x 25 columns]

# %%
# assigning determined inputed values back to dataframe

X_train[cont_lst] = missing_vals
X_train.head()
# Out:
#               id    parcelid  bathroomcnt  bedroomcnt  calculatedbathnbr  \
# 35549  2835290.0  10928726.0          2.0         3.0                2.0
# 18097  1855117.0  11925904.0          3.0         4.0                3.0
# 18950  2809180.0  11991988.0          1.0         3.0                1.0
# 36943  1030712.0  10850571.0          1.0         2.0                1.0
# 52305  2871267.0  12669704.0          2.0         4.0                2.0
#
#        calculatedfinishedsquarefeet  finishedsquarefeet12    fips  \
# 35549                        1244.0                1244.0  6037.0
# 18097                        2898.0                2898.0  6037.0
# 18950                        1166.0                1166.0  6037.0
# 36943                         803.0                 803.0  6037.0
# 52305                        2166.0                2166.0  6037.0
#
#        fullbathcnt    latitude  ...  roomcnt  yearbuilt  \
# 35549          2.0  34166955.0  ...      0.0     1943.0
# 18097          3.0  34120410.0  ...      0.0     1993.0
# 18950          1.0  34078141.0  ...      0.0     1922.0
# 36943          1.0  34177765.0  ...      0.0     1949.0
# 52305          2.0  33809933.0  ...      0.0     1954.0
#
#       structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 35549                    32283.0            58562.0          2016.0
# 18097                   518378.0           926843.0          2016.0
# 18950                   147520.0           459788.0          2016.0
# 36943                    99494.0           497472.0          2016.0
# 52305                    66047.0           139547.0          2016.0
#
#        landtaxvaluedollarcnt  taxamount  censustractandblock  transactiondate  \
# 35549                26279.0     764.51         6.037125e+13       2017-06-30
# 18097               408465.0   10802.46         6.037432e+13       2017-04-17
# 18950               312268.0    5518.32         6.037193e+13       2017-04-20
# 36943               397978.0    6099.58         6.037139e+13       2017-07-07
# 52305                73500.0    1770.95         6.037651e+13       2017-09-19
#
#              propertylandusedesc
# 35549  Single Family Residential
# 18097  Single Family Residential
# 18950  Single Family Residential
# 36943  Single Family Residential
# 52305  Single Family Residential
#
# [5 rows x 28 columns]

# %%
# checking the dataset information

X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29293 entries, 35549 to 36098
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            29293 non-null  float64
#  1   parcelid                      29293 non-null  float64
#  2   bathroomcnt                   29293 non-null  float64
#  3   bedroomcnt                    29293 non-null  float64
#  4   calculatedbathnbr             29293 non-null  float64
#  5   calculatedfinishedsquarefeet  29293 non-null  float64
#  6   finishedsquarefeet12          29293 non-null  float64
#  7   fips                          29293 non-null  float64
#  8   fullbathcnt                   29293 non-null  float64
#  9   latitude                      29293 non-null  float64
#  10  longitude                     29293 non-null  float64
#  11  lotsizesquarefeet             29293 non-null  float64
#  12  propertycountylandusecode     29293 non-null  object
#  13  propertylandusetypeid         29293 non-null  float64
#  14  rawcensustractandblock        29293 non-null  float64
#  15  regionidcity                  29293 non-null  float64
#  16  regionidcounty                29293 non-null  float64
#  17  regionidzip                   29293 non-null  float64
#  18  roomcnt                       29293 non-null  float64
#  19  yearbuilt                     29293 non-null  float64
#  20  structuretaxvaluedollarcnt    29293 non-null  float64
#  21  taxvaluedollarcnt             29293 non-null  float64
#  22  assessmentyear                29293 non-null  float64
#  23  landtaxvaluedollarcnt         29293 non-null  float64
#  24  taxamount                     29293 non-null  float64
#  25  censustractandblock           29293 non-null  float64
#  26  transactiondate               29293 non-null  object
#  27  propertylandusedesc           29293 non-null  object
# dtypes: float64(25), object(3)
# memory usage: 6.5+ MB
